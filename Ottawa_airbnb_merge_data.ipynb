# %%
REVIEWS_URL = 'https://ids-storage-football-prediction.s3-eu-west-1.amazonaws.com/data_mmwd/reviews.csv'
REVIEWS_AND_POLARITY_URL = 'https://ids-storage-football-prediction.s3-eu-west-1.amazonaws.com/data_mmwd/reviews_en_polarity.csv'
CALENDAR_URL = 'https://ids-storage-football-prediction.s3-eu-west-1.amazonaws.com/data_mmwd/calendar.csv'
LISTINGS_URL = 'https://ids-storage-football-prediction.s3-eu-west-1.amazonaws.com/data_mmwd/listings.csv'
MEAN_POLARITY_URL = 'https://ids-storage-football-prediction.s3-eu-west-1.amazonaws.com/data_mmwd/polarity_mean.csv'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from scipy import stats
import seaborn as sns
from scipy.linalg import sqrtm
from sklearn.metrics import mean_squared_error
from math import sqrt

plt.style.use('fivethirtyeight')

# %%
listings = pd.read_csv(LISTINGS_URL)
polarity = pd.read_csv(MEAN_POLARITY_URL, index_col=['Unnamed: 0'])

# %%
listings.shape
# Out:
# (2613, 74)

# %%
polarity.columns
# Out:
# Index(['listing_id', 'polarity'], dtype='object')

# %%
polarity.columns = ['id', 'polarity']

# %%
polarity.head()
# Out:
#        id  polarity
# 0   36642    0.8070
# 1   59258    0.9850
# 2  158824    0.7430
# 3  261065    0.8304
# 4  336692    0.9537

# %%
df = pd.merge(listings, polarity, on='id')

# %%
df.head()
# Out:
#        id                          listing_url  ...  reviews_per_month polarity
# 0   36642   https://www.airbnb.com/rooms/36642  ...               0.69   0.8070
# 1   59258   https://www.airbnb.com/rooms/59258  ...               0.01   0.9850
# 2  158824  https://www.airbnb.com/rooms/158824  ...               0.06   0.7430
# 3  261065  https://www.airbnb.com/rooms/261065  ...               0.59   0.8304
# 4  336692  https://www.airbnb.com/rooms/336692  ...               0.22   0.9537
#
# [5 rows x 75 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2183 entries, 0 to 2182
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            2183 non-null   int64
#  1   listing_url                                   2183 non-null   object
#  2   scrape_id                                     2183 non-null   int64
#  3   last_scraped                                  2183 non-null   object
#  4   name                                          2183 non-null   object
#  5   description                                   2143 non-null   object
#  6   neighborhood_overview                         1614 non-null   object
#  7   picture_url                                   2183 non-null   object
#  8   host_id                                       2183 non-null   int64
#  9   host_url                                      2183 non-null   object
#  10  host_name                                     2183 non-null   object
#  11  host_since                                    2183 non-null   object
#  12  host_location                                 2181 non-null   object
#  13  host_about                                    1398 non-null   object
#  14  host_response_time                            1638 non-null   object
#  15  host_response_rate                            1638 non-null   object
#  16  host_acceptance_rate                          1911 non-null   object
#  17  host_is_superhost                             2183 non-null   object
#  18  host_thumbnail_url                            2183 non-null   object
#  19  host_picture_url                              2183 non-null   object
#  20  host_neighbourhood                            454 non-null    object
#  21  host_listings_count                           2183 non-null   int64
#  22  host_total_listings_count                     2183 non-null   int64
#  23  host_verifications                            2183 non-null   object
#  24  host_has_profile_pic                          2183 non-null   object
#  25  host_identity_verified                        2183 non-null   object
#  26  neighbourhood                                 1614 non-null   object
#  27  neighbourhood_cleansed                        2183 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      2183 non-null   float64
#  30  longitude                                     2183 non-null   float64
#  31  property_type                                 2183 non-null   object
#  32  room_type                                     2183 non-null   object
#  33  accommodates                                  2183 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                2183 non-null   object
#  36  bedrooms                                      2018 non-null   float64
#  37  beds                                          2174 non-null   float64
#  38  amenities                                     2183 non-null   object
#  39  price                                         2183 non-null   object
#  40  minimum_nights                                2183 non-null   int64
#  41  maximum_nights                                2183 non-null   int64
#  42  minimum_minimum_nights                        2183 non-null   int64
#  43  maximum_minimum_nights                        2183 non-null   int64
#  44  minimum_maximum_nights                        2183 non-null   int64
#  45  maximum_maximum_nights                        2183 non-null   int64
#  46  minimum_nights_avg_ntm                        2183 non-null   float64
#  47  maximum_nights_avg_ntm                        2183 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              2183 non-null   object
#  50  availability_30                               2183 non-null   int64
#  51  availability_60                               2183 non-null   int64
#  52  availability_90                               2183 non-null   int64
#  53  availability_365                              2183 non-null   int64
#  54  calendar_last_scraped                         2183 non-null   object
#  55  number_of_reviews                             2183 non-null   int64
#  56  number_of_reviews_ltm                         2183 non-null   int64
#  57  number_of_reviews_l30d                        2183 non-null   int64
#  58  first_review                                  2183 non-null   object
#  59  last_review                                   2183 non-null   object
#  60  review_scores_rating                          2183 non-null   float64
#  61  review_scores_accuracy                        2181 non-null   float64
#  62  review_scores_cleanliness                     2181 non-null   float64
#  63  review_scores_checkin                         2180 non-null   float64
#  64  review_scores_communication                   2180 non-null   float64
#  65  review_scores_location                        2180 non-null   float64
#  66  review_scores_value                           2180 non-null   float64
#  67  license                                       0 non-null      float64
#  68  instant_bookable                              2183 non-null   object
#  69  calculated_host_listings_count                2183 non-null   int64
#  70  calculated_host_listings_count_entire_homes   2183 non-null   int64
#  71  calculated_host_listings_count_private_rooms  2183 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   2183 non-null   int64
#  73  reviews_per_month                             2183 non-null   float64
#  74  polarity                                      2183 non-null   float64
# dtypes: float64(19), int64(23), object(33)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (2183, 75)

# %%
df.reset_index(inplace=True)

# %%
df = df.drop(['picture_url', 'host_id', 'host_url',
       'host_name', 'host_since', 'host_location', 'host_about',
       'host_response_time', 'host_response_rate', 'host_acceptance_rate',
       'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
       'host_neighbourhood', 'host_listings_count',
       'host_total_listings_count', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
       'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
       'maximum_minimum_nights', 'minimum_maximum_nights',
       'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
       'availability_30', 'availability_60', 'availability_90', 'availability_365', 'calendar_last_scraped', 'license', 'instant_bookable',
       'calculated_host_listings_count',
       'calculated_host_listings_count_entire_homes',
       'calculated_host_listings_count_private_rooms',
       'calculated_host_listings_count_shared_rooms', 'neighborhood_overview', 'bathrooms',
       'first_review',
       'last_review', 'review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value', 'reviews_per_month'
       ], axis=1)

# %%
df.shape
# Out:
# (2183, 21)

# %%
df = df[df['bedrooms'].notna()]

# %%
df.shape
# Out:
# (2018, 21)

# %%
df = df[df['description'].notna()]

# %%
df = df[df['beds'].notna()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1981 entries, 0 to 2182
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   index                   1981 non-null   int64
#  1   id                      1981 non-null   int64
#  2   listing_url             1981 non-null   object
#  3   scrape_id               1981 non-null   int64
#  4   last_scraped            1981 non-null   object
#  5   name                    1981 non-null   object
#  6   description             1981 non-null   object
#  7   latitude                1981 non-null   float64
#  8   longitude               1981 non-null   float64
#  9   property_type           1981 non-null   object
#  10  room_type               1981 non-null   object
#  11  accommodates            1981 non-null   int64
#  12  bathrooms_text          1981 non-null   object
#  13  bedrooms                1981 non-null   float64
#  14  beds                    1981 non-null   float64
#  15  amenities               1981 non-null   object
#  16  price                   1981 non-null   object
#  17  number_of_reviews       1981 non-null   int64
#  18  number_of_reviews_ltm   1981 non-null   int64
#  19  number_of_reviews_l30d  1981 non-null   int64
#  20  polarity                1981 non-null   float64
# dtypes: float64(5), int64(7), object(9)
# memory usage: 340.5+ KB

# %%
df.head()
# Out:
#    index      id  ... number_of_reviews_l30d  polarity
# 0      0   36642  ...                      0    0.8070
# 1      1   59258  ...                      0    0.9850
# 2      2  158824  ...                      0    0.7430
# 3      3  261065  ...                      1    0.8304
# 4      4  336692  ...                      0    0.9537
#
# [5 rows x 21 columns]

# %%
df.to_csv('merged_listings_and_polarity.csv')

# %%
df.sort_values(by=['polarity', 'number_of_reviews'], ascending=False).head()
# Out:
#       index        id  ... number_of_reviews_l30d  polarity
# 121     121   6475461  ...                      3    0.9991
# 1790   1790  39297349  ...                      1    0.9987
# 1391   1391  33135723  ...                      2    0.9985
# 700     700  19783655  ...                      0    0.9983
# 758     758  21184041  ...                      0    0.9982
#
# [5 rows x 21 columns]
